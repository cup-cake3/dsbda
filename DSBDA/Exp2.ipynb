# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv("student2.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  Year_Birth  math score reading score writing score  \
# 0                    none        1970        72.0            72            74
# 1               completed        1961         NaN            na             A
# 2                    none        1958        90.0            95            93
# 3                    none        1967         NaN           NaN            44
# 4                    none        1989        76.0            78            75
#
#   Dt_Admission College_Fees
# 0      6/16/14   $84,835.00
# 1      6/15/14   $57,091.00
# ...

# %%
miss=["n/a","na","--"]
df=pd.read_csv("student2.csv",na_values=miss)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  Year_Birth  math score  reading score  \
# 0                    none        1970        72.0           72.0
# 1               completed        1961         NaN            NaN
# 2                    none        1958        90.0           95.0
# 3                    none        1967         NaN            NaN
# 4                    none        1989        76.0           78.0
#
#   writing score Dt_Admission College_Fees
# 0            74      6/16/14   $84,835.00
# 1             A      6/15/14   $57,091.00
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# Year_Birth                     0
# math score                     2
# reading score                  2
# writing score                  0
# Dt_Admission                   0
# College_Fees                   5
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
math=df["math score"]

# %%
sorted(math)
# Out:
# [0.0,
#  8.0,
#  18.0,
#  19.0,
#  22.0,
#  23.0,
#  24.0,
#  26.0,
#  27.0,
#  27.0,
#  28.0,
#  29.0,
#  29.0,
#  29.0,
#  30.0,
#  30.0,
#  32.0,
#  32.0,
#  32.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  35.0,
#  35.0,
#  35.0,
#  35.0,
#  36.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  38.0,
#  38.0,
#  38.0,
#  39.0,
#  39.0,
#  39.0,
#  39.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  40.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  43.0,
#  43.0,
#  43.0,
#  43.0,
#  43.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  46.0,
#  47.0,
#  47.0,
#  47.0,
#  47.0,
#  47.0,
#  47.0,
#  47.0,
#  47.0,
#  47.0,
#  47.0,
#  48.0,
#  48.0,
#  48.0,
#  48.0,
#  48.0,
#  48.0,
# ...

# %%
q1,q3=np.percentile(math,[25,75])

# %%
p1=np.percentile(math,[25,75])
p1
# Out:
# array([57., 77.])

# %%
q1,q3
# Out:
# (57.0, 77.0)

# %%
iqr=(q3-q1)

# %%
iqr
# Out:
# 20.0

# %%
lowerbound=q1-(1.5*iqr)

# %%
upperbound=q3+(1.5*iqr)

# %%
lowerbound,upperbound
# Out:
# (27.0, 107.0)

# %%
df[df["math score"]<27]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 145  female        group C                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 787  female        group B                some college      standard
# 842  female        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
#
#     test preparation course  Year_Birth  math score  reading score  \
# 17                     none        1958        18.0           32.0
# 59                     none        1964         0.0           17.0
# 145                    none        1984        22.0           39.0
# 338                    none        1954        24.0           38.0
# ...

# %%
df[df["math score"]<27].count()
# Out:
# gender                         8
# race/ethnicity                 8
# parental level of education    8
# lunch                          8
# test preparation course        8
# Year_Birth                     8
# math score                     8
# reading score                  8
# writing score                  8
# Dt_Admission                   8
# College_Fees                   8
# dtype: int64

# %%
df[df["math score"]>107].count()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# Year_Birth                     0
# math score                     0
# reading score                  0
# writing score                  0
# Dt_Admission                   0
# College_Fees                   0
# dtype: int64

# %%
df["fees"]=df["College_Fees"].str.replace(',','').str.replace('$','').str.replace('.',"").astype(int)//100
# Out:
# C:\Users\ishan\AppData\Local\Temp/ipykernel_18628/716034963.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["fees"]=df["College_Fees"].str.replace(',','').str.replace('$','').str.replace('.',"").astype(int)//100

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  Year_Birth  math score  reading score  \
# 0                      none        1970        72.0           72.0
# ...

# %%
from datetime import date

# %%
y=pd.DatetimeIndex(df['Dt_Admission']) #YYYY-MM-DD

# %%
y
# Out:
# DatetimeIndex(['2014-06-16', '2014-05-13', '2014-04-08', '2014-03-17',
#                '2014-01-29', '2014-01-18', '2014-01-11', '2014-01-11',
#                '2013-12-27', '2013-12-09',
#                ...
#                '2013-10-12', '2013-05-14', '2013-03-28', '2013-01-05',
#                '2012-09-15', '2012-08-24', '2012-08-17', '2014-05-27',
#                '2014-02-23', '2014-01-10'],
#               dtype='datetime64[ns]', name='Dt_Admission', length=993, freq=None)
